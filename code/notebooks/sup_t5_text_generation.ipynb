# %% [markdown]
# ### Setup

# %%
# !nvidia-smi
# Out:
# Mon Aug 22 17:09:55 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0    25W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Utils

# %%
# %%capture
# %pip install -r /content/feedback/code/requirements.txt
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
import os
import gc
import glob
import json
import pandas as pd
import numpy as np

from sklearn.metrics import f1_score, log_loss
import matplotlib.pyplot as plt
from itertools import chain

from copy import deepcopy
from dataclasses import dataclass

import torch
from transformers import DataCollatorWithPadding
from torch.utils.data import DataLoader

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.checkpoint

import math
import shutil

from torch.optim import AdamW
from transformers import get_cosine_schedule_with_warmup
from transformers.trainer_pt_utils import get_parameter_names

import pdb
import random
from collections import OrderedDict

from accelerate import Accelerator
from tqdm.auto import tqdm

import re


from datasets import Dataset
from tokenizers import AddedToken
from transformers import AutoTokenizer
from transformers import T5Tokenizer, T5ForConditionalGeneration


from transformers import (
    AdamW,
    T5ForConditionalGeneration,
    T5Tokenizer,
    get_linear_schedule_with_warmup
)

from transformers.optimization import  Adafactor
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
config =json.loads("""{
    "debug": false,
    "seed": 453,
    "model_checkpoint": "t5-large",
    
    "batch_size": 2,
    "warmup_pct": 0.025,
    "num_epochs": 5,
    
    "gradient_checkpointing": false,
    "fp16": true,
    "grad_accumulation": 4,
    "eval_frequency": 2400,
    "max_length": 512,

    "model_dir": "../models/T5_generator",

    "project": "feedback-prize-ea",
    "run_name": "rb-t5-data-augmentation",
    "patience": 10,
    
    "fpe_dataset_dir": "../datasets/feedback-prize-effectiveness",
    "fold_path": "../datasets/processed/cv_map_topics_10_folds.parquet",
    "train_essay_fpe21_dir": "../datasets/processed/fpe_21_train_essays.parquet",
    "train_essay_fpe22_dir": "../datasets/processed/fpe_22_train_essays.parquet",
    "test_essay_fpe22_dir": "../datasets/processed/fpe_22_test_essays.parquet",
    "n_folds":10
}""")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
df = pd.read_csv(os.path.join(config["fpe_dataset_dir"], "train.csv"))
fold_df = pd.read_parquet(config["fold_path"])
df = pd.merge(df, fold_df, on="essay_id", how="left")
essay_df = pd.read_parquet(config["train_essay_fpe22_dir"])

topic_df = pd.read_csv("../datasets/processed/fpe_2021_topics.csv")
topic_df = topic_df[["essay_id", "prompt", "topic_num"]].copy()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def relaxed_search(text, substring, min_length=2, fraction=0.99999):
    """
    Returns substring's span from the given text with the certain precision.
    """

    position = text.find(substring)
    substring_length = len(substring)
    if position == -1:
        half_length = int(substring_length * fraction)
        half_substring = substring[:half_length]
        half_substring_length = len(half_substring)
        if half_substring_length < min_length:
            return [-1, 0]
        else:
            return relaxed_search(text=text,
                                  substring=half_substring,
                                  min_length=min_length,
                                  fraction=fraction)

    span = [position, position+substring_length]
    return span


def build_span_map(discourse_list, essay_text):
    reading_head = 0
    to_return = dict()

    for cur_discourse in discourse_list:
        if cur_discourse not in to_return:
            to_return[cur_discourse] = []

        matches = re.finditer(re.escape(r'{}'.format(cur_discourse)), essay_text)
        for match in matches:
            span_start, span_end = match.span()
            if span_end <= reading_head:
                continue
            to_return[cur_discourse].append(match.span())
            reading_head = span_end
            break

    # post process
    for cur_discourse in discourse_list:
        if not to_return[cur_discourse]:
            print("resorting to relaxed search...")
            to_return[cur_discourse] = [relaxed_search(essay_text, cur_discourse)]
    return to_return


def get_substring_span(texts, mapping):
    result = []
    for text in texts:
        ans = mapping[text].pop(0)
        result.append(ans)
    return result


def process_input_df(anno_df, notes_df):
    """pre-process input dataframe

    :param df: input dataframe
    :type df: pd.DataFrame
    :return: processed dataframe
    :rtype: pd.DataFrame
    """
    notes_df = deepcopy(notes_df)
    anno_df = deepcopy(anno_df)

    #------------------- Pre-Process Essay Text --------------------------#
    anno_df["discourse_text"] = anno_df["discourse_text"].apply(lambda x: x.strip())  # pre-process
    if "discourse_effectiveness" in anno_df.columns:
        anno_df = anno_df[["discourse_id", "essay_id", "discourse_text",
                           "discourse_type", "discourse_effectiveness"]].copy()
    else:
        anno_df = anno_df[["discourse_id", "essay_id", "discourse_text", "discourse_type", "uid"]].copy()

    tmp_df = anno_df.groupby("essay_id")[["discourse_id", "discourse_text"]].agg(list).reset_index()
    tmp_df = pd.merge(tmp_df, notes_df, on="essay_id", how="left")
    tmp_df["span_map"] = tmp_df[["discourse_text", "essay_text"]].apply(
        lambda x: build_span_map(x[0], x[1]), axis=1)
    tmp_df["span"] = tmp_df[["discourse_text", "span_map"]].apply(
        lambda x: get_substring_span(x[0], x[1]), axis=1)

    all_discourse_ids = list(chain(*tmp_df["discourse_id"].values))
    all_discourse_spans = list(chain(*tmp_df["span"].values))
    span_df = pd.DataFrame()
    span_df["discourse_id"] = all_discourse_ids
    span_df["span"] = all_discourse_spans
    span_df["discourse_start"] = span_df["span"].apply(lambda x: x[0])
    span_df["discourse_end"] = span_df["span"].apply(lambda x: x[1])
    span_df = span_df.drop(columns="span")

    anno_df = pd.merge(anno_df, span_df, on="discourse_id", how="left")
    return anno_df
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
df = process_input_df(df, essay_df)
df = pd.merge(df, essay_df, on="essay_id", how="left")
df = pd.merge(df, topic_df, on="essay_id", how="left")

def get_model_input_text(prompt, left_context, right_context, discourse_type, discourse_effectiveness):

    to_return = [
        f"Generate text for {discourse_effectiveness} {discourse_type}", 
        f"Prompt: {prompt}",
        f"Left Context: {left_context}",
        f"Right Context: {right_context}"
    ]
    return "|| \n".join(to_return)

def get_model_output_text(discourse_text):
    return discourse_text


df["left_context"] = df[["essay_text", "discourse_start"]].apply(lambda x: x[0][:x[1]], axis=1)
df["right_context"] = df[["essay_text", "discourse_end"]].apply(lambda x: x[0][x[1]:], axis=1)
df["model_input"] = df[["prompt", "left_context", "right_context", "discourse_type", "discourse_effectiveness"]].apply(
    lambda x: get_model_input_text(x[0], x[1], x[2], x[3], x[4]), axis=1
)

df["model_output"] = df["discourse_text"].apply(lambda x: get_model_output_text(x))
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# resorting to relaxed search...

# %%
df[["model_input", "model_output"]].sample(1)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#                                              model_input  \
# 29990  Generate text for Ineffective Evidence|| \nPro...
#
#                                             model_output
# 29990  NASA has lots of it i believed the rich people...

# %%
model = T5ForConditionalGeneration.from_pretrained(config["model_checkpoint"])
tokenizer = T5Tokenizer.from_pretrained(config["model_checkpoint"], model_max_length=config["max_length"])

ckpt = torch.load("../models/T5_generator/t5_generator_left_right_context.pth.tar")
model.load_state_dict(ckpt["state_dict"])

del ckpt
gc.collect()
torch.cuda.empty_cache()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.75G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]

# %%
accelerator = Accelerator()
model = accelerator.prepare(model)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
model.eval()
config["max_length"] = 512
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def generate_text(input_text, num_sents):
    test_tokenized = tokenizer.encode_plus(
        input_text, 
        add_special_tokens=True, 
        return_tensors="pt", 
        truncation=True, 
        max_length=config["max_length"], 
        padding=False
    )
    test_input_ids  = test_tokenized["input_ids"]
    test_attention_mask = test_tokenized["attention_mask"]
    
    beam_outputs = model.generate(
        input_ids = test_input_ids.to("cuda"),
        attention_mask = test_attention_mask.to("cuda"),
        max_length=config["max_length"],
        early_stopping=True,
        num_beams=15,
        num_return_sequences=num_sents,
        no_repeat_ngram_size=2,
        temperature=2.0,
        do_sample=True,
    )

    to_return = []
    for beam_output in beam_outputs:
        sent = tokenizer.decode(beam_output, skip_special_tokens=True, clean_up_tokenization_spaces=True)
        to_return.append(sent)
    torch.cuda.empty_cache()
    return to_return
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def generate_aumentation(essay_id, input_df, num_sents=5):
    example_df = input_df[input_df["essay_id"]==essay_id].copy()
    example_df = example_df.sort_values(by="discourse_start")
    example_df = example_df.reset_index(drop=True)
    
    essay_text = example_df["essay_text"].values[0]
    starts = example_df["discourse_start"].tolist()
    ends = example_df["discourse_end"].tolist()
    
    starts.append(-1)
    
    fillers = [essay_text[:starts[0]]]
    
    for s, e in zip(ends, starts[1:]):
        fillers.append(essay_text[s:e])
               
    generated_texts = dict()

    for idx, (row_id, row) in enumerate(example_df.iterrows()):
        model_input = row.model_input
        generated_texts[idx] = generate_text(model_input, num_sents=num_sents)
               
    generated_df = pd.DataFrame(generated_texts).T
    generated_df.columns = [f"t5_generated_{i}" for i in range(num_sents)]
    result_df = pd.concat([example_df, generated_df], axis=1)
    result_df = result_df.drop(columns=["essay_text", "topic_num", "left_context", "right_context", "model_input", "model_output"])
    
    generated_essays = []
    for col_idx in range(num_sents):
        current_essay = fillers[0]
        for idx in range(len(generated_df)):
            current_essay += generated_df.iloc[idx][f"t5_generated_{col_idx}"]
            current_essay += fillers[idx+1]
        generated_essays.append(current_essay)   
    return result_df, essay_text, generated_essays
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
all_essay_ids = df["essay_id"].unique().tolist()
random.shuffle(all_essay_ids)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
cache_df = pd.read_csv("../datasets/augmented_data/t5_essays.csv")
cache_df["essay_id"] = cache_df["essay_id"].apply(lambda x: str(x).split("_")[0])
done_essays = cache_df["essay_id"].unique().tolist()
len(done_essays)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 2202

# %%
for essay_num in tqdm(range(len(all_essay_ids))):
    essay_id = all_essay_ids[essay_num]
    if essay_id in done_essays:
        print(f"skipping {essay_id}")
        continue
        
    result_df, original_essay, generated_essays = generate_aumentation(essay_id, df, num_sents=5)
    
    result_df.to_csv(f"../datasets/augmented_data/worker_3/df_{essay_id}.csv", index=False)
    
    for idx, aug_text in enumerate(generated_essays):
        content = {f"{essay_id}": aug_text}
        with open(f"../datasets/augmented_data/worker_3/{essay_id}_augmented_{idx}.json", "w") as f:
            json.dump(content, f)
    torch.cuda.empty_cache()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   0%|          | 0/4191 [00:00<?, ?it/s]
# skipping ED1EFE97C40F
# skipping E570BB4A5B5B
# skipping 60714BE8146A
# skipping 0491C7BFA9B4
# skipping 72ECF408E30D
# skipping 34263BB26432
# skipping FB2ED8D952A6
# skipping 28E2327785FC
# skipping 7A0F4648B341
# skipping EF835E27D5A3
# skipping 4E48D58E859A
# skipping FBD21BB50633
# skipping 9B0344F83C66
# skipping 1136D95D28E7
# skipping B8EAF80A1409
# skipping 57CE6ED06513
# skipping DC4E11A259D8
# skipping 07A023BE2629
# skipping 6621856784A9
# skipping 653F5908B3BD
# skipping 4D05FF3E63BE
# skipping F19978B8C2A7
# skipping B3CB635C4341
# skipping 83C1CC6938F4
# skipping 01AFC67DF935
# skipping FD0C32EA0E5B
# skipping DCDE7152B94E
# skipping B3963F9DB39C
# skipping 3F63FCA1BD42
# skipping B237EA09433F
# skipping F6F60CA6E983
# skipping E37D480CD473
# skipping 34B96B0F6EBD
# skipping 4122443C74C6
# skipping D34DFB9BF717
# skipping E7C5E12F4E84
# skipping 7F8D472D06A1
# skipping 5E57B80BFC66
# skipping 52579F4BBE4E
# skipping E87BDAB97148
# skipping A98E8EFFC8A9
# skipping 13FB62D377E3
# skipping 1BDC5F527974
# skipping 9706F8E7D534
# skipping DDBE5B47593D
# skipping DE7F02980A1D
# skipping 28314B1AC842
# skipping 17C80F3C80B3
# skipping B83D6D54324F
# skipping E310FB5D4752
# skipping 9FBD2D259388
# skipping B902933C58CB
# skipping A156FB0E388E
# skipping 87A3A28A5EB8
# skipping C0BA22AD7F2A
# skipping 71BF2F475B65
# skipping 505A9D10C001
# skipping 9D0934987831
# skipping 4F6084AE3A42
# skipping E2BB0AA98EA5
# skipping 1357329AAA22
# skipping 0C952AD5C1EA
# skipping 4BB688100D15
# skipping 746BC0AD4761
# skipping C10C521A47C3
# skipping 709156BCF733
# skipping 0242719E9969
# skipping A8A25F94F5B6
# skipping F86C71E10A78
# skipping 2A35A23BE3C3
# skipping 765F4BB0381E
# skipping CC06612E842A
# skipping D69B5E55F39D
# skipping 1E7C6D8AB2A2
# skipping ADAE8A21CE9E
# skipping 2C670AC05A4E
# skipping C6C49435744E
# skipping 1006FE578078
# skipping B84458707731
# skipping C38334385924
# skipping 9D254F20E5D8
# skipping 6C991A1A6C39
# skipping 91962F622C5A
# skipping D891B1BFC6F6
# skipping 4722B4D2C6E7
# skipping A7D201133DAD
# skipping 5EA13764DA34
# skipping 1BD82BE8C639
# skipping 53B21C3A440F
# skipping 73D6F19E24BD
# skipping 2D73663127C2
# skipping 763EF698F56B
# skipping CBC776495BE0
# skipping D994B051E6A2
# skipping 5E461378597B
# skipping 764CF7C9DF70
# skipping 32D94C1BA4A5
# skipping 7E97F03304F1
# skipping 7E3E96B4F614
# skipping E88DDA2FB4EA
# skipping 0527DB04DCC0
# skipping 5729D5AE055C
# skipping 836A3BBFA12D
# skipping 66ABB3042298
# skipping 3F8C6F9EBDEB
# skipping AF9AAA672210
# skipping 127670CABA7C
# skipping 2DFFB145BE07
# skipping 4BD30FA12457
# skipping 0BC016A285DC
# skipping 495DF8DE2896
# skipping 611532F64D30
# skipping C4C3A58C5939
# skipping A5FBF588B2F4
# skipping FA62EE04FAFA
# skipping AF5C9DA63FB1
# skipping 057DACBB2B12
# skipping 1EA525C7EBF3
# skipping 5CC530A8C191
# skipping 3D9CBC4F434F
# skipping A165EEC2E930
# skipping CC54E936E3FA
# skipping 547C43CF3291
# skipping D2D4AD42B2E1
# skipping D169E2520168
# skipping 0D3AA8470CC4
# skipping ABC9EBAB6670
# skipping 457D9B0CF71F
# skipping C9CAB778C94E
# skipping 9AEBAA2BE62D
# skipping 0AC09FD13E72
# skipping 4E1F37A9728A
# skipping A90D70556372
# skipping 088C3E8EBAE7
# skipping 6141232BA814
# skipping EE0229233F51
# skipping 4A12B5FDB00B
# skipping 26453BA910DE
# skipping B0AD7021AB07
# skipping 193B0EE3BF45
# skipping 8F4907E2D511
# skipping EB5021B098DD
# skipping 75C2D5CE58D0
# skipping 54A8F5B2420A
# skipping 9D8B3825C355
# skipping 8FF749312D49
# skipping F0740AF01F22
# skipping 2C0D4A3D4590
# skipping A5DA0D5410DE
# skipping 10E7A0414D14
# skipping 91B00B44402B
# skipping E24F801F1C4A
# skipping EF0D75BF48DA
# skipping ABC4770058F6
# skipping 594169D56D3F
# skipping 15DF5443F192
# skipping D0733E25A2C7
# skipping EDC00F1B2823
# skipping D962FD67FF4C
# skipping 23982EC8FF86
# skipping F30B7DE35BBC
# skipping 9165D265E932
# skipping 85FD6510C00A
# skipping CAE2A78F6FF2
# skipping 9D967AA72C96
# skipping 2D13EF90C1FA
# skipping 1F07CBB60940
# skipping 7C8094BF63DE
# skipping FB528A6DAF0C
# skipping 274CB6483DB9
# skipping CB2385831D75
# skipping AEBBFD25000D
# skipping FB05272DAD57
# skipping 939718B6780D
# skipping 218490FD2E1B
# skipping 85417E9C78E7
# skipping E4824CBFEEBD
# skipping 8855A0898835
# skipping 19C1FF204DD1
# skipping B0D5228E9FBD
# skipping 628019536B7A
# skipping 2A2F04CC199E
# skipping 0BF9F64D6FD1
# skipping 2BB14634D9FE
# skipping 2FDB1B6086C9
# skipping AB1C30F7B3FA
# skipping FB8F29B936CE
# skipping 7863164BA896
# skipping 6F8200CADE90
# skipping 728DD08A8342
# skipping 7D462AA4E1FC
# skipping 9000217714BE
# skipping BC0D9F77A3DA
# skipping F562A7ADF5CD
# skipping 575107B10B0B
# skipping 11461A6C46C6
# skipping 7534BB13F2D4
# skipping 64EE7AB92E51
# skipping 9C88FA75BF98
# skipping D6B7EE7B040D
# skipping 336F8093CF86
# skipping 1E7013131796
# skipping 231FDA202B25
# skipping 0B6B5E779566
# skipping 8842FE99EC98
# skipping 7323FA189167
# skipping 306BCA39D2E9
# skipping DB4B78DAADCB
# skipping 74DD3C49B848
# skipping 79C245E3C9C2
# skipping D1B06A3C02B3
# skipping EAF6BCA737BD
# skipping A4104F998C73
# skipping 76D57BCC7A10
# skipping 8D69369DEDA2
# skipping 22049B234D6C
# skipping 9A7F7ACCC1D9
# skipping 41DAE20A16DF
# skipping 4E8255A83429
# skipping F73047E4DC36
# skipping 352CEEDDF08C
# skipping 7A2D0B189298
# skipping B471DC1A142D
# skipping D0187B1F88F7
# skipping 09035E72A3AE
# skipping 6641EA903719
# skipping 45A87F46D89C
# skipping 5D1A08FC3563
# skipping A6B380D5DEBB
# skipping 3C89B5224126
# skipping 02DACD6071FD
# skipping DC83F2FC879B
# skipping 237968EDE68A
# skipping 7263826C2217
# skipping 1028F5A588AA
# skipping 8C62721A56E0
# skipping 9DE0959F746D
# skipping 7811A36C87ED
# skipping 690D4166C20C
# skipping 509A6BA813C0
# skipping 24FA36D49DB7
# skipping 6183574CA5FC
# skipping 5AE4D1E1C5F6
# skipping 7748D6B51DD8
# skipping 997D5145CB33
# skipping 2CCC9DCFE253
# skipping 2E1C25D6F265
# skipping 84D821F541E7
# skipping 32C41C1CBA06
# skipping 57807B412545
# skipping 79766A7A3911
# skipping F0F0CD67E436
# skipping 4380C1BD3461
# skipping EC7C81E59E9E
# skipping 4D4B09BC09A5
# skipping 2C8521890B5A
# skipping 38D227AB68A0
# skipping 00944C693682
# skipping F456754DA472
# skipping C3C4D847175E
# skipping 1A5D1D1C4F14
# skipping 23C6ED53A179
# skipping 9244152BE347
# skipping 3E6D1917A314
# skipping 04217B837E28
# skipping C83EB6623D24
# skipping 9C1132980450
# skipping F737FB396F2E
# skipping 42B977C6E77F
# skipping 93106B20FE87
# skipping 974383195606
# skipping B4025ED10B7E
# skipping 44D318388E8C
# skipping 7F63036D0C59
# skipping B269D53897D9
# skipping 04ACF5873DE9
# skipping F574FF3D3C6A
# skipping 18AC57CFB338
# skipping F69CFE5AEDCA
# skipping B0C3BBF86B9B
# skipping D2F5E24CEEAA
# skipping FF9E159AEEF0
# skipping C5382404A84B
# skipping D31481D3B465
# skipping BC2CAB7DB6F0
# skipping 2D21E920F1B0
# skipping BE5B1803777E
# skipping 1248C86D1F56
# skipping 57596DF3AD20
# skipping A3BFEB7818C7
# skipping D9BB6C11F6E3
# skipping D44639122EAF
# skipping 1AD1F738D48B
# skipping 146818D2FAF1
# skipping 083C3AE77587
# skipping 48898FA30C5B
# skipping B3388EF1E80C
# skipping D9B85CAE8834
# skipping 5C9E6CCEAF57
# skipping 7C057FA3B1CA
# skipping 578C014A7BBE
# skipping 558299F3D69E
# skipping AD005493F9BF
# skipping 0350A994E363
# skipping A1F48D16C67B
# skipping F245631F4D97
# skipping 3F8C4D2CA16E
# skipping 3C8360258FE5
# skipping 21A162D4B0CB
# skipping FAFDA54C78E1
# skipping 758703E5BF73
# skipping 2F4428039BA4
# skipping 2B4BE109A9D7
# skipping 3B3A47EA684D
# skipping BD3AE65B1740
# skipping 17A4777DCC71
# skipping 7E2EF53A56BC
# skipping 84EC5D05E3E2
# skipping 5E879A28D710
# skipping AF0BC75F4DBC
# skipping C9313379E449
# skipping B7BC85276656
# skipping 28823EC65BA2
# skipping 0F13AFF35C0C
# skipping FF7164909305
# skipping A737705B81A4
# skipping 24BC9F21DAE0
# skipping D30490AE8641
# skipping FB8C67F0AC92
# skipping F20C7101F09D
# skipping DDCF594E44D1
# skipping 5F931A3FF8F9
# skipping 1F30B1F276A7
# skipping BBEE06BD484C
# skipping E2A9D1243AF9
# skipping 0DC3BDC76434
# skipping 4A8B8527DD14
# skipping FD9CC83A98C5
# skipping 0EF91AC5D457
# skipping FB6A513EBFC6
# skipping CE0CDCBDFD26
# skipping 45AE96545D1A
# skipping 8D2688E8706E
# skipping F634BC92DC39
# skipping 8F85E4509835
# skipping 268675CF9C2B
# skipping F49FF10DA5C2
# skipping 67325C66D1E0
# skipping CF43485AE351
# skipping 0825571D1A47
# skipping 47F56748F9C4
# skipping 7927FA99C0AD
# skipping BDCD981437BB
# skipping 86A511A55117
# skipping D7C33D289E26
# skipping 16180FD0AEF8
# skipping 39F8DB13BB4F
# skipping B7AE34990F95
# skipping 14FE56852B95
# skipping BD195459F3B9
# skipping 32E3A5BDD0B2
# skipping 2FA703D6B89C
# skipping 7CEB4836BAFA
# skipping 75818DBD4DA2
# skipping 7BE3B580C5DB
# skipping AAE4139C25E1
# skipping 0F6250B6D784
# skipping B79ABAFC71D1
# skipping 620419154DDF
# skipping 87258EA0A73C
# skipping B3526897360F
# skipping 0029F4D19C3F
# skipping 01B3A57AB13D
# skipping 405D9D4958DF
# skipping 0910E011143F
# skipping 7BDF02EBF9F9
# skipping 7770B90F2FEF
# skipping 66FE148BE39B
# skipping 56EE0E1D79CB
# skipping 61BABBBB9822
# skipping B2D57A646363
# skipping 5B38B644790E
# skipping 9B94E6359412
# skipping C9962F63C98A
# skipping B4B605F897BC
# skipping 3165FA4998BC
# skipping 0D220BA8BA23
# skipping 015BB7DA58EE
# skipping 27837D0F399E
# skipping 93C0100883BB
# skipping 53DE53537B56
# skipping E7DFEA5C3B73
# skipping AA3F8EC40764
# skipping 7903205CD088
# skipping A59C88B945A3
# skipping C584DEDB2BAB
# skipping 81745F5FFCB9
# skipping 67348F433E43
# skipping 1300CBEB1F39
# skipping 9E3A10CC0A72
# skipping CD7714C1464D
# skipping 2B5011D4C860
# skipping DF1287CDBCF6
# skipping 419C8EFADABA
# skipping 451E43CF8A30
# skipping 4C30EEDA3A8F
# skipping 73B7AA4CFB1C
# skipping 0300455258CB
# skipping 82BC11EA5744
# skipping AA45F6AB9AA9
# skipping 05A06DE4B96C
# skipping 745F2414FCA9
# skipping 59A71CF8491A
# skipping EA2BAEFCE4F2
# skipping C39C5D9C9ED8
# skipping B7E936A82959
# skipping 4409FED98F5A
# skipping 811DE32FCE53
# skipping 178FCB8C1D80
# skipping 5C8E678EACDD
# skipping 353CAC9AC658
# skipping 4F616FEC40E0
# skipping 441A5D13BCF3
# skipping F33EB52BBB43
# skipping 5C5EB17E8684
# skipping 916E7E75FC4A
# skipping 8F6F0CD4986A
# skipping 00B144412785
# skipping 2751851F289B
# skipping 63F717BB8C2D
# skipping FC39D2688C50
# skipping 900A879708F0
# skipping E97670F90297
# skipping 76537E8BFF12
# skipping A148C659E98B
# skipping 50DA28892569
# skipping 7820048B53C8
# skipping 2D08A68E70CD
# skipping FBB861DBF984
# skipping 8C4ED47912C3
# skipping 390900163076
# skipping A4E6E2D5658D
# skipping A1274B901F55
# skipping 44E343ECD9B7
# skipping 0C1BFE5E9F69
# skipping AA42E3966A3C
# skipping 632C8DA9E2B1
# skipping 84FFEF07FB0D
# skipping 2B48EAC02BF3
# skipping 8003F62C4A0C
# skipping 30935D02377A
# skipping 0ACB0E08934E
# skipping 6C2348EA83BB
# skipping 3A46013B0369
# skipping 0C0C473FA794
# skipping 0045BE2791A2
# skipping 7CF49F831E85
# skipping 710819DE9003
# skipping B111395C3C6E
# skipping 7EAB25FDB984
# skipping 20E41EFD4FB8
# skipping 709820813997
# skipping 2DEC6F2AE21A
# skipping 441097905601
# skipping C42EBA5B3529
# skipping AC871BBF14B5
# skipping 0FC4B7E09462
# skipping 8F8E1AECFE27
# skipping D91B2369C76D
# skipping 237E08ECC729
# skipping CBD364987E2D
# skipping 5940D91292F8
# skipping E23D057A2674
# skipping 75C65F266CFD
# skipping 23CC3629CEC0
# skipping 2ABF91C208B8
# skipping F881AA0F9990
# skipping 86A3A166AA67
# skipping EDDFFD34DBD4
# skipping 754CED955EFD
# skipping 6A2F708CAA8B
# skipping 44DBB635DEB1
# skipping 85E38E898579
# skipping 219F04FD37B6
# skipping D43178C538DF
# skipping 9E1B8D4EA6B0
# skipping 5690C4B1DE7E
# skipping D12165A1A427
# skipping B0CCFA21F82C
# skipping 58F2F77D8FD6
# skipping 0548DE784D69
# skipping C06AB6F566C8
# skipping 97249F8DF48F
# skipping 95874BE012EB
# skipping D32804D6C269
# skipping 099985A2A99C
# skipping CF882151082B
# skipping 9FDB425F1FE9
# skipping A954E3B54194
# skipping 1590FD8BEA8E
# skipping C0E55316F183
# skipping 41F94D05D278
# skipping ED321E901AC7
# skipping 6874FC63CF20
# skipping 3085F5ECF4B0
# skipping 7E492FFD9778
# skipping 24E0B6DB7B49
# skipping D1AF5CE5040E
# skipping 95CB51270760
# skipping 9447D5C6EA03
# skipping FC481B7DC611
# skipping 2007A7232687
# skipping 1801F16E35E4
# skipping F3A980C4613A
# skipping 37FC9DB2D1DB
# skipping 45EF6A4EDB1A
# skipping B154F5F9DADF
# skipping CD0A8E34A5C0
# skipping 3D97B580A127
# skipping 4B201D2C2152
# skipping DAA0F90A5C8F
# skipping D145F56FADED
# skipping 691DF95F51C3
# skipping 216A05AF987E
# skipping 1E6CE8FB9C96
# skipping ADFE2CDB6FF1
# skipping E3E50332E6FD
# skipping 384D9E9B4369
# skipping 436CA2153EB6
# skipping B02AD8EE0DF0
# skipping 0A6324CE9AD0
# skipping 8DA3804EEB25
# skipping 4ACC669C808C
# skipping 387FEC6C2CB7
# skipping 4642829BC8A4
# skipping C08ABCCFBF4D
# skipping 231A89552BD3
# skipping 30A900519B84
# skipping 3FF0FB7E93BD
# skipping 487739AC4B1E
# skipping 82223F37DDCC
# skipping C323ACC08DC7
# skipping BCF95C5F4A60
# skipping 27347E260F1C
# skipping DAC85E32DCED
# skipping 3C693CBFEFB5
# skipping BDA93024CF81
# skipping DA5E92093978
# skipping 0A618B980D2D
# skipping AAA72CBAC7F8
# skipping 600959D8A343
# skipping 6E1B4AF3CDC3
# skipping 13457D2F2557
# skipping 7F6795CE405C
# skipping 643B41BE89EE
# skipping 60C439A28A94
# skipping E5B1751B2798
# skipping 07C6107B301F
# skipping 6776B92E4513
# skipping 6B56C630FFC5
# skipping E61D1C3EC9DD
# skipping 4F68A8CE6F27
# skipping AE3C9DE4FA94
# skipping 8B2B8A57D84B
# skipping F2AE26666823
# skipping F3C003AF7423
# skipping 4E6E66266A2A
# skipping C319BB7948FB
# skipping 360F4E7D2631
# skipping A49E1A5FA91B
# skipping 45D156498F73
# skipping 61607C674FA3
# skipping E53B5654C0E2
# skipping C513DCACFD01
# skipping 40331978F344
# skipping 62FC97D29846
# skipping 8CD442C14869
# skipping 50F1D8786126
# skipping FFC43F453EF6
# skipping 1541D4F15A1B
# skipping 942ECB176B3A
# skipping 0C1D8179D5F3
# skipping E49CCE901992
# skipping 6F142E71AEF1
# skipping 9DBB8B0C3367
# skipping 3EBF97F2F31A
# skipping 108C28958E5B
# skipping A791047275B9
# skipping 3F15318ECD44
# skipping A0DEA37279E9
# skipping 31998D3364B9
# skipping BF070C66EE96
# skipping 681AE0381A53
# skipping 20D81D1BE1A6
# skipping D0B6CE1FA38E
# skipping B8757E80EB9D
# skipping 2EEE167F8C62
# skipping 551BD9A8F311
# skipping 18658BB1E5FF
# skipping 0CE521F8D172
# skipping A588F05DC41F
# skipping 2D10F2D7A580
# skipping BB4A53A0A9E0
# skipping CC3A5AD37340
# skipping BBF34C059226
# skipping F772E0A3152A
# skipping D34054ADD2FB
# skipping 7EC34F21069A
# skipping 15F80BF4B3C9
# skipping 05F5B97B159A
# skipping B25D365F5C1C
# skipping 6058577A0EB1
# skipping 81EE0A1746B9
# skipping 3BA0E26A657F
# skipping 52432D25C86B
# skipping 255F29455E8B
# skipping 612EB8B104BC
# skipping F296C5CF54D7
# skipping 446A878D528E
# skipping A8C8456C352B
# skipping 8A60E09A7062
# skipping F84CB4D0589A
# skipping F86616365497
# skipping F27957F2AC4B
# skipping 5D48FA3291DE
# skipping A8FD11F16108
# skipping 63687EA6EB28
# skipping C816339C4D91
# skipping 82B3CF7114C7
# skipping AA7A452C4D9F
# skipping A3EA9A580A6A
# skipping 3B5EE97C7C53
# skipping 2ECCE525D35D
# skipping 749E1B13022A
# skipping F776F9881474
# skipping ADBB29D9E179
# skipping 7E54AA9ADF2B
# skipping 2C469434A463
# skipping A451B2D00666
# skipping 899E6252BD6F
# skipping 236ACE5E8FC3
# skipping D4E3104E7591
# skipping 8D6EE82E31D0
# skipping 5875D6BFC687
# skipping 451D81265E8E
# skipping 6FB4BDEE27AE
# skipping 9EABE5CEBE94
# skipping 1A30D1140E7D
# skipping F6DA09C9C0C1
# skipping FE3CA06DDCA1
# skipping 688BD7FE6932
# skipping 6AFC2BA228ED
# skipping 4EDB197A680E
# skipping 8EF9BE158AD3
# skipping 0DDCAFAEA487
# skipping 850401568E9C
# skipping 30045307DB37
# skipping 43C31084455B
# skipping ED6B6A38F98D
# skipping 541CC72DE4AE
# skipping 6A59D543AE54
# skipping ECFAD2825EC6
# skipping 7E873F1E93C2
# skipping 9BDB556267D8
# skipping B8FB806ECDA3
# skipping FBE4AAD08E49
# skipping 9604D30A25AB
# skipping 6E6BCEE073C6
# skipping 909404A6C673
# skipping CC4EEADA5262
# skipping 3A748C1D650A
# skipping B4FD96336393
# skipping 300B76F37D8E
# skipping D6AAE9DC566D
# skipping 20897B41AFB8
# skipping 04DEFB0B11C5
# skipping D69416DBA6F4
# skipping 951BF63BC21A
# skipping 350376FA39BD
# skipping 163A7C9FCF34
# skipping 3BD4064486ED
# skipping 0FF049B01070
# skipping 58B7F73691D2
# skipping 90A95275B80D
# skipping C0897AC15921
# skipping A2A749DEC4BE
# skipping FFD97A99CEBA
# skipping DBE4FF1CA803
# skipping 8C15FC3C3BCB
# skipping 2E4AFCD3987F
# skipping 0FC97658A027
# skipping 95765CEE7D74
# skipping C536086A1C31
# skipping EF7631952FB3
# skipping D9B5F55E6705
# skipping 75B64811DC65
# skipping CAC4E6021973
# skipping 42F881EA857A
# skipping F880CDD90C95
# skipping 67D58F9FA53C
# skipping C48AEB2F1FC2
# skipping C1CC3C045CCB
# skipping 63B0C1CE1743
# skipping B947F9493FAF
# skipping 33475A71956C
# skipping 73A5A2871074
# skipping CD33A5B0A307
# skipping E98F49492C8B
# skipping 75EDF0FEA5F1
# skipping 794A0704B01C
# skipping 3ECE3D9AD865
# skipping FD05FDCEA11B
# skipping 72D8B5600A8F
# skipping 0A5BA91AA8B5
# skipping 057AF0C42467
# skipping 346D40A69BBF
# skipping 4C471936CD75
# skipping 45EBD1AF6D37
# skipping 3254ADC7B428
# skipping D0DF7AB8B493
# skipping DECDC46197E4
# skipping 916958737B60
# skipping F17A4EF296EB
# skipping 0D91FC8A9FE7
# skipping 4C6B05BD5A81
# skipping 497E63C46A84
# skipping 6C50FC009033
# skipping 53F1450AF8DF
# skipping 65552A741D2A
# skipping DBCC1F8F92B5
# skipping 5145FF65E5BE
# skipping AAA9670F8168
# skipping C4FC27B38A8F
# skipping 331502EB3762
# skipping A63EC24F1DD4
# skipping 66B37D7DE0F6
# skipping 313229323B6E
# skipping A3960A410B74
# skipping 44A5406282B8
# skipping F55EF5BB5CB9
# skipping 0EAF5E712F0D
# skipping 67780BCAD15F
# skipping 1BB48664CC6A
# skipping A7642F5617E0
# skipping 41E9768ADAF5
# skipping D594C2B7582D
# skipping EED4EEF4523A
# skipping 49EC678EC9BB
# skipping 75C4CC1ABECF
# skipping 20D57DEC3EF5
# skipping 671D0569C835
# skipping 8783DB652376
# skipping 6B6A7138292B
# skipping 31B358884D0B
# skipping 38EEEB5BC11C
# skipping 4178B01DEEC6
# skipping E313EE03F35F
# skipping 89039D21E960
# skipping C5569B2725B4
# skipping 6CA078E0C93F
# skipping 87F529DB9D27
# skipping 0195CE164102
# skipping 327AAC23CF5D
# skipping 552E2FEC5EFA
# skipping E67A118F9AFA
# skipping FFF868E06176
# skipping B709F976724E
# skipping 2C021FD670EB
# skipping DCDE1C43C218
# skipping DC1DA01985EF
# skipping 37771E9C2A8D
# skipping 11823089B61E
# skipping 8B5A7E5D7BB5
# skipping 877F6174E222
# skipping 4D55C9731228
# skipping A95B8B50E0C1
# skipping 1463D1D9EC8F
# skipping 4F46B0E32EB7
# skipping 299C0AA4D716
# skipping C65C1B3AA577
# skipping F9FFECDE9A53
# skipping D0B2235710B6
# skipping 2D5E45654C18
# skipping 57280EFE34F4
# skipping 01F69867D1BE
# skipping 94000E9DF26E
# skipping EA441360E42C
# skipping 4FAC3B29417F
# skipping F03E03FE5D3C
# skipping 7EE7A20BBBD4
# skipping 5CB2FF0429F3
# skipping B216794ACCCA
# skipping DF76BBCD85B1
# skipping 912848EF6E5E
# skipping 4797D4343628
# skipping 426D179A5178
# skipping 3A88FA2C4060
# skipping CC82A1D80D1A
# skipping 7672B22A2D8F
# skipping 63268F421EE1
# skipping C6C50AA537AF
# skipping 8563982CE8C7
# skipping 35694DE1F9DE
# skipping 3CB7F7FC1F29
# skipping 96BF2953ED8F
# skipping 8B4A0DD4A3AE
# skipping 28FF2BE0AB1A
# skipping 8AC3B251DDDF
# skipping C579A4D6151E
# skipping 6F0ECB93B03B
# skipping 360DAF43CFF9
# skipping A455B4430327
# skipping B4994C771190
# skipping 72E8EFB1A713
# skipping 2E4427B65439
# skipping 3B20A3B52316
# skipping 5CE073B74680
# skipping 1F8354F0A861
# skipping F10231811C61
# skipping 46607966C5C2
# skipping 79662DEC0A1B
# skipping 1C7FDCD3337C
# skipping 017302FBA532
# skipping 2EEB19BB460B
# skipping 297F3F4B6B58
# skipping 65E50A262677
# skipping 6CA3EC0D0FC8
# skipping A3041B0D7D5E
# skipping 727DE3CD0AEC
# skipping 57ED566E615C
# skipping 3C4368A07D88
# skipping 46A92C87B030
# skipping 78D5951B96C5
# skipping AF90C62BA52D
# skipping A15A51E83757
# skipping AB0403712FA9
# skipping F038426B8B5A
# skipping E09942089364
# skipping 023CEE52C08C
# skipping 8387BDBA7F9B
# skipping 291AAEA628E1
# skipping DFB074E89515
# skipping 2017D32A0639
# skipping 0E5BCFB10650
# skipping 03CD4C5553A4
# skipping 5C3B7683D560
# skipping 30B3A5EACADC
# skipping 53858BE44997
# skipping 0CE6E6BF8EA4
# skipping 00BD97EA4041
# skipping A2237589F0FE
# skipping 40BDB6D6B9A7
# skipping 66D810E0A3D1
# skipping 881F756EF94A
# skipping ECF63F6AB48E
# skipping 1D7E734B4A3D
# skipping A138DF27F153
# skipping 2E0AF5C8526F
# skipping 56C208138AC9
# skipping BC2333002957
# skipping D1200B924E51
# skipping F6A2AEEBDF0D
# skipping 7277DA6BE697
# skipping 6300E798D425
# skipping DC364EC72968
# skipping 516557988F8B
# skipping A67828F23302
# skipping D20BEF9C2CD7
# skipping BF295AF91B15
# skipping 571BE3159B48
# skipping FEF42864AE28
# skipping 465FAD6FEDC4
# skipping FB6C139752AA
# skipping F71A1E42E4B5
# skipping EAED55A47DC5
# skipping D6E7A5034205
# skipping A053080C69A4
# skipping 9207F5E4EA09
# skipping 75A635A498F4
# skipping 992AD0F505B0
# skipping 09DB075C4ACE
# skipping 25F9B9BAA02A
# skipping 7301B174090E
# skipping BD0D555216AB
# skipping ECFCAAECAD31
# skipping 6EEAB9FBADDF
# skipping DE2BFF400952
# skipping 569CBA2B3B8F
# skipping BDC4070CF21E
# skipping 89D979169B57
# skipping B867F487B9F3
# skipping 0EEE131E57EC
# skipping B460B20EE678
# skipping 698E89BCF1FD
# skipping BE1F20C5B099
# skipping D18B9F0D2CB4
# skipping 84DB11599420
# skipping 50964348BC11
# skipping 52835AA731FA
# skipping 0CA9AC7879C9
# skipping CA582B3F191F
# skipping 946C874A9CCD
# skipping 146550E45D18
# skipping A3B1F9DB5721
# skipping F3928951775C
# skipping 94E1D46A0544
# skipping 5BDF483698A5
# skipping 8E938A38BA43
# skipping 7B1981581BC7
# skipping 2865585E0E34
# skipping CF8F8964A2FB
# skipping 7A532625FFDC
# skipping 945DC098A326
# skipping B133FCABD0AF
# skipping 9579E25F6CCC
# skipping D4BC716CE227
# skipping 67BD359D8BD2
# skipping 2E810318FBD2
# skipping 0557D6B9B3E5
# skipping 10D09AB4D6C7
# skipping 5C2A497012B9
# skipping 3AA63F8F7D47
# skipping 51CD300AB688
# skipping DBC53691CD0A
# skipping 99037D0468C8
# skipping 5FB75CCB31F8
# skipping 0A5B8761B187
# skipping 97B417D0B9D9
# skipping 0BB0E957B6FE
# skipping 53E064890ABC
# skipping 326DEFF8D486
# skipping 952CB87D4897
# skipping 016A403802E8
# skipping 455D0FE2839E
# skipping D81428AC9545
# skipping 7E026B760EA0
# skipping 7429789954ED
# skipping 325B922888A7
# skipping 4094C6225C49
# skipping EB16CD7EC3E6
# skipping 163F5BC5FDF3
# skipping 0BD82CC1FC8C
# skipping FA87416EF173
# skipping A6D70DC96AB3
# skipping 439B4B707E10
# skipping A2FA635C9590
# skipping 4478B3244F49
# skipping B7BD520BE938
# skipping E743F9AC8BBE
# skipping EA58637960FB
# skipping 2C20FC3AC128
# skipping AABDFA8D20B1
# skipping 910B844ACCA1
# skipping C0AC393B1DC9
# skipping 6ED32B9136F8
# skipping 29450AD2A452
# skipping FA3E37900E3D
# skipping 56AC4BE71C2F
# skipping FD8FFDC82D48
# skipping 259CAA746857
# skipping B9F4BF3DC949
# skipping 18DD6D2A09F2
# skipping 827472D8F8A9
# skipping E8D0E2444ADD
# skipping C5A56B482FAA
# skipping 309BE8E1DCF1
# skipping 21C75B3F290A
# skipping 0F10DC1AE015
# skipping B651AEF954C3
# skipping 02F89B4E55CF
# skipping B365484CCA8F
# skipping D4442F757F02
# skipping 2A53E83B0090
# skipping A8E73414941A
# skipping 3BBD17BCB443
# skipping 57E1C649E187
# skipping 3EFA3EE80C51
# skipping FA2BC6C3A09B
# skipping 0B5BFD4E5904
# skipping EA238A2AE63A
# skipping 6C5A6D1D0C13
# skipping A319351F1036
# skipping 3B61207AD210
# skipping A3D23CFB2043
# skipping AA0B42CF00A6
# skipping BDFEDD161F03
# skipping 88B8F8666DA0
# skipping B2EE7ADD5BFA
# skipping 3ADF2D3323BE
# skipping 1E5EFF5360E2
# skipping D8D1FA118E4A
# skipping B6B2D2FC8F3D
# skipping 87A974F87B12
# skipping A860BB507256
# skipping A2A80E683990
# skipping 473FF163E44A
# skipping 9C88B308AF78
# skipping C3A369E86900
# skipping 37DFBAA507EE
# skipping 0E01BA28D3D9
# skipping FEE1811CCE57
# skipping D5F6593584F8
# skipping DBBF3EF47E93
# skipping 1D6188632F9B
# skipping 93E10E079796
# skipping 00E3F86E3E6A
# skipping FB7DB9D91933
# skipping 6F271187D67D
# skipping 486F1C72E20D
# skipping CE120A8B4336
# skipping F074E15D7250
# skipping 689AA040C1A2
# skipping CAE63BBF4546
# skipping 80889A79B329
# skipping 5934838B26AD
# skipping 6C3DE9491C5E
# skipping 700BD7047E86
# skipping 8BBA4BC818BA
# skipping 66E83D44F4A3
# skipping 8A8F6BCA1D23
# skipping AC5AEE18D31E
# skipping 14CC75D0E9D0
# skipping 30C6A72F5821
# skipping C2E0FC6F097D
# skipping 086603D5B319
# skipping 00D304153840
# skipping 2CFBD4AA7BE5
# skipping 6C9A5A8FA2F9
# skipping 6A8D21EBA6DB
# skipping 116A338694CB
# skipping ECF8296772E9
# skipping 3946C28D4D7E
# skipping 964639CCF90C
# skipping 129427624B81
# skipping 0B52B1F1265B
# skipping 63FC4B44DCF4
# skipping 879F248F7934
# skipping BBDD46456082
# skipping E28D7D67A8F7
# skipping EB382D12574F
# skipping 563F7AD6C619
# skipping B32F41984B27
# skipping 8212DA6D0656
# skipping A38F35A9F711
# skipping 378005A2C405
# skipping 9A8B992CE622
# skipping CD4B9F6B311B
# skipping 9F7080A8AC9E
# skipping 1DC6485ABFF6
# skipping C62E3292FB47
# skipping 66BB82BD76B2
# skipping E3EC600A1754
# skipping 7D681EE99FF3
# skipping 74F07823BCB9
# skipping 5BD888B4E549
# skipping BA47D0FEA751
# skipping 6FD0E82AB64D
# skipping B79D1BD832C1
# skipping A681057AC54F
# skipping 9756E31C449F
# skipping 7E6236F28B06
# skipping 31F4831C794D
# skipping AC588B53A805
# skipping CA4E67209D3C
# skipping F62295251C0D
# skipping 61E75F6539D8
# skipping 759754F07F7F
# skipping B6F03D0CEABE
# skipping F00B4D036D97
# skipping 4BB2F265CFEB
# skipping 3679FD464B98
# skipping BE243683124A
# skipping 11168209A49C
# skipping 51634BBDF223
# skipping F2FA6B69F481
# skipping 484C49CBDA30
# skipping F2B86853339B
# skipping 49586CD6A649
# skipping 687134C8A628
# skipping 15E106AF20A7
# skipping 9A529A48D35F
# skipping 09770DECD26C
# skipping 7A347C69D3D1
# skipping 9D42FF4BDA82
# skipping A0181C244D0D
# skipping 88E81B040A5A
